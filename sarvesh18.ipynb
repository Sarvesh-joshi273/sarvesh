# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarvesh-joshi273/sarvesh/blob/main/sarvesh18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("ford.csv")

# %%
df
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1       Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2       Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3      Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4      Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 17961   B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962   B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963   Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964      KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965   Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# ...

# %%
df.head(10)
# Out:
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1   Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2   Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3  Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4  Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0
# 5  Fiesta  2015  10500       Manual    35432   Petrol  145  47.9         1.6
# 6    Puma  2019  22500       Manual     2029   Petrol  145  50.4         1.0
# 7  Fiesta  2017   9000       Manual    13054   Petrol  145  54.3         1.2
# 8    Kuga  2019  25500    Automatic     6894   Diesel  145  42.2         2.0
# 9   Focus  2018  10000       Manual    48141   Petrol  145  61.4         1.0

# %%
df.tail(5)
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 17961  B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962  B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963  Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964     KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965  Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 17961         1.4
# 17962         1.0
# 17963         1.6
# 17964         1.2
# 17965         1.0

# %%
df.shape
# Out:
# (17966, 9)

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df.duplicated().sum()
df = df.drop_duplicates()
df
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1       Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2       Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3      Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4      Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 17961   B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962   B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963   Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964      KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965   Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# ...

# %%
df.shape
# Out:
# (17812, 9)

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  17812.000000  17812.000000   17812.000000  17812.000000  17812.000000
# mean    2016.862396  12269.556310   23381.146362    113.315012     57.908696
# std        2.052039   4736.285417   19419.011045     62.034603     10.132696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000   10000.000000     30.000000     52.300000
# 50%     2017.000000  11288.000000   18277.000000    145.000000     58.900000
# 75%     2018.000000  15295.000000   31098.500000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17812.000000
# mean       1.350623
# std        0.432581
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
df['price'].min()
df['price'].max
df['price'].mean()
df['price'].median()
# Out:
# 11288.0

# %%
df['mileage'].min()
df['mileage'].max()
df['mileage'].mean()
df['mileage'].median()
# Out:
# 18277.0

# %%
df['year'].min()
df['year'].max()
df['year'].mean()
df['year'].median()
# Out:
# 2017.0

# %%
df[['price','mileage','year','engineSize','mpg']].hist(bins=30, figsize=(12,8))
plt.show()

# %%
sns.countplot(x='fuelType', data=df)
plt.title("fuelType")
plt.show()

# %%
sns.countplot(x='transmission', data=df)
plt.title("transmission")
plt.show()

# %%
sns.countplot(x='model', data=df)
plt.title("model")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['int64','float64'])
corr = numeric_df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
df[['fuelType','transmission']].head()
df = pd.get_dummies(df, columns=['fuelType','transmission'])
df.filter(like='fuelType').head()
df.filter(like='transmission').head()
# Out:
#    transmission_Automatic  transmission_Manual  transmission_Semi-Auto
# 0                    True                False                   False
# 1                   False                 True                   False
# 2                   False                 True                   False
# 3                   False                 True                   False
# 4                    True                False                   False

# %%
X = df[['mileage','year','engineSize','mpg']]
X = pd.DataFrame(StandardScaler().fit_transform(X), columns=X.columns)

print(X.head())
# Out:
#     mileage      year  engineSize       mpg
# 0 -0.382994  0.067059   -0.810561 -0.020597
# 1 -0.736317  0.554393   -0.810561 -0.020597
# 2 -0.562616  0.067059   -0.810561 -0.020597
# 3 -0.665405  1.041726    0.345325 -1.737858
# 4 -1.127749  1.041726   -0.810561 -0.908836

# %%
df[['price','mileage','year','engineSize','mpg']].hist(bins=30, figsize=(12,8))
plt.show()

# %%
sns.heatmap(df.select_dtypes(include=['int64','float64']).corr(), annot=True, cmap='coolwarm')
plt.show()
